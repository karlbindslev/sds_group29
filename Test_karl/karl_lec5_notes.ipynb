# %%
# Plotting

import matplotlib.pyplot as plt

# %matplotlib inline

import pandas as pd
import seaborn as sns # high level plotting library

iris = sns.load_dataset('iris')
tips = sns.load_dataset('tips')

print(tips.head(3))
print(len(tips))
tips.total_bill.value_counts()

# cut into categorial data
x = tips.total_bill
cuts = np.arange(0,70,10)
pd.cut(x,cuts).value_counts()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 244
# (10, 20]    130
# (20, 30]     65
# (30, 40]     22
# (0, 10]      17
# (40, 50]      9
# (50, 60]      1
# Name: total_bill, dtype: int64

# %%
# Plotting with matplotlib

fig, ax = plt.subplots(figsize = (10,4.5))
ax.set_xlim([0,60])
ax.set_ylim([0,80])
ax.hist(x)
plt.style.use('default') # set style (colors, background, size, gridlines etc.)
plt.rcParams['figure.figsize'] = 10, 4 # set default size of plots
plt.rcParams.update({'font.size': 18})

# %%
# Plotting with pandas

x.plot.hist()

# %%
# Ploitting with seaborn

sns.distplot(x)
# Out:
# /Users/karlbindslev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Plotting data frames with matplotlib

plt.scatter(x=tips['total_bill'], y=tips['tip'])

# %%
# Plotting dataframes with seaborn

sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex', size=5)
# Out:
# /Users/karlbindslev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/karlbindslev/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, size=5, aspect=2)
